# %%
import qiskit
from qiskit_dynamics.models import QuantumSystemModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 import qiskit
# ----> 2 from qiskit_dynamics.models import QuantumSystemModel
#
# ImportError: cannot import name 'QuantumSystemModel' from 'qiskit_dynamics.models' (C:\Users\mdram\miniconda3\envs\qiskit\Lib\site-packages\qiskit_dynamics\models\__init__.py)

# %% [markdown]
# Qiskit Dynamics is an open-source project for building, transforming, and solving models of quantum systems in Qiskit.

# %%
import jax
jax.config.update("jax_enable_x64", True)

# tell JAX we are using CPU
jax.config.update('jax_platform_name', 'cpu')

# %%
# If it's part of another library, the import path will change
# from my_quantum_package import QuantumSystemModel
QuantumSystemModel(
    static_hamiltonian=31.41592653589793 * N(0) + (-1.0367255756846319 * N(0) @ (N(0) + -1 * I(0))),
    drive_hamiltonian_coefficients=['d0'],
    drive_hamiltonians=[0.06283185307179587 * X(0)],
    static_dissipators=[],
    drive_dissipator_coefficients=[],
    drive_dissipators=[],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # If it's part of another library, the import path will change
#       2 # from my_quantum_package import QuantumSystemModel
# ----> 3 QuantumSystemModel(
#       4     static_hamiltonian=31.41592653589793 * N(0) + (-1.0367255756846319 * N(0) @ (N(0) + -1 * I(0))),
#       5     drive_hamiltonian_coefficients=['d0'],
#       6     drive_hamiltonians=[0.06283185307179587 * X(0)],
#       7     static_dissipators=[],
#       8     drive_dissipator_coefficients=[],
#       9     drive_dissipators=[],
#      10 )
#
# NameError: name 'QuantumSystemModel' is not defined

# %%
print(str(Q0_model))
